# %%
from datetime import datetime, timedelta
import yfinance as yf
import pandas as pd

# %%
#official starts here#####

# %%
# for bitcoin (BTC)

# %%
# 1min interval data for bitcoin-usd
btc_1m = yf.download(tickers = "BTC-USD" , interval = "1m", start="2021-05-01", end="2021-05-08")
btc_1m.to_csv('1m_btc.csv')
btc_1m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2021-05-01 06:00:00+01:00  58090.585938  58090.585938  58090.585938
# 2021-05-01 06:01:00+01:00  58102.464844  58102.464844  58102.464844
# 2021-05-01 06:02:00+01:00  57978.636719  57978.636719  57978.636719
# 2021-05-01 06:03:00+01:00  58010.042969  58010.042969  58010.042969
# 2021-05-01 06:04:00+01:00  57925.429688  57925.429688  57925.429688
# ...                                 ...           ...           ...
# 2021-05-08 05:55:00+01:00  58037.777344  58037.777344  58037.777344
# 2021-05-08 05:56:00+01:00  58047.187500  58047.187500  58047.187500
# 2021-05-08 05:57:00+01:00  58035.878906  58035.878906  58035.878906
# 2021-05-08 05:58:00+01:00  58041.152344  58041.152344  58041.152344
# 2021-05-08 05:59:00+01:00  58080.804688  58080.804688  58080.804688
#
#                                   Close     Adj Close  Volume
# ...

# %%
# 5min interval data for bitcoin-usd
btc_5m = yf.download(tickers = "BTC-USD" , interval = "5m", start="2021-04-01", end="2021-05-08")
btc_5m.to_csv('5m_btc.csv')
btc_5m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2021-04-01 06:00:00+01:00  59095.675781  59130.832031  59076.429688
# 2021-04-01 06:05:00+01:00  59074.414062  59130.820312  59074.414062
# 2021-04-01 06:10:00+01:00  59153.109375  59171.652344  59123.585938
# 2021-04-01 06:15:00+01:00  59107.507812  59107.507812  59061.402344
# 2021-04-01 06:20:00+01:00  59045.898438  59045.898438  59025.460938
# ...                                 ...           ...           ...
# 2021-05-08 05:35:00+01:00  58309.132812  58400.812500  58291.898438
# 2021-05-08 05:40:00+01:00  58296.710938  58296.710938  58240.277344
# 2021-05-08 05:45:00+01:00  58227.671875  58227.671875  58147.238281
# 2021-05-08 05:50:00+01:00  58069.046875  58087.472656  58062.082031
# 2021-05-08 05:55:00+01:00  58037.777344  58080.804688  58035.878906
#
#                                   Close     Adj Close     Volume
# ...

# %%
#for Ethereum (ETH)

# %%
# 1min interval data for ethereum-usd
eth_1m = yf.download(tickers = "ETH-USD" , interval = "1m", start="2021-05-01", end="2021-05-08")
eth_1m.to_csv('1m_eth.csv')
eth_1m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Datetime
# 2021-05-01 06:00:00+01:00  2844.666748  2844.666748  2844.666748  2844.666748
# 2021-05-01 06:01:00+01:00  2846.512695  2846.512695  2846.512695  2846.512695
# 2021-05-01 06:02:00+01:00  2840.295410  2840.295410  2840.295410  2840.295410
# 2021-05-01 06:03:00+01:00  2841.338135  2841.338135  2841.338135  2841.338135
# 2021-05-01 06:04:00+01:00  2838.657959  2838.657959  2838.657959  2838.657959
# ...                                ...          ...          ...          ...
# 2021-05-08 05:55:00+01:00  3563.831543  3563.831543  3563.831543  3563.831543
# 2021-05-08 05:56:00+01:00  3563.111816  3563.111816  3563.111816  3563.111816
# 2021-05-08 05:57:00+01:00  3563.434082  3563.434082  3563.434082  3563.434082
# 2021-05-08 05:58:00+01:00  3561.995850  3561.995850  3561.995850  3561.995850
# ...

# %%
# 5min interval data for ethereum-usd
eth_5m = yf.download(tickers = "ETH-USD" , interval = "5m", start="2021-04-01", end="2021-05-08")
eth_5m.to_csv('5m_eth.csv')
eth_5m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Datetime
# 2021-04-01 06:00:00+01:00  1919.896851  1923.101196  1919.896851  1922.987549
# 2021-04-01 06:05:00+01:00  1922.384521  1922.384521  1921.422485  1922.059448
# 2021-04-01 06:10:00+01:00  1923.374878  1924.010498  1923.123413  1923.123413
# 2021-04-01 06:15:00+01:00  1922.830444  1922.830444  1920.332520  1920.332520
# 2021-04-01 06:20:00+01:00  1919.344238  1919.344238  1918.899536  1918.899536
# ...                                ...          ...          ...          ...
# 2021-05-08 05:35:00+01:00  3567.293701  3574.982666  3567.293701  3569.814941
# 2021-05-08 05:40:00+01:00  3568.785889  3571.547607  3568.785889  3571.547607
# 2021-05-08 05:45:00+01:00  3574.910889  3576.998291  3569.835449  3573.929932
# 2021-05-08 05:50:00+01:00  3573.296875  3573.296875  3565.013428  3567.100098
# ...

# %%
# for Dogecoin

# %%
# 1min interval data for dogecoin-usd
doge_1m = yf.download(tickers = "DOGE-USD" , interval = "1m", start="2021-05-01", end="2021-05-08")
doge_1m.to_csv('doge_1m.csv')
doge_1m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                Open      High       Low     Close  Adj Close  \
# Datetime
# 2021-05-01 06:00:00+01:00  0.362049  0.362049  0.362049  0.362049   0.362049
# 2021-05-01 06:01:00+01:00  0.362517  0.362517  0.362517  0.362517   0.362517
# 2021-05-01 06:02:00+01:00  0.359991  0.359991  0.359991  0.359991   0.359991
# 2021-05-01 06:03:00+01:00  0.360444  0.360444  0.360444  0.360444   0.360444
# 2021-05-01 06:04:00+01:00  0.358728  0.358728  0.358728  0.358728   0.358728
# ...                             ...       ...       ...       ...        ...
# 2021-05-08 05:56:00+01:00  0.732105  0.732105  0.732105  0.732105   0.732105
# 2021-05-08 05:57:00+01:00  0.733294  0.733294  0.733294  0.733294   0.733294
# 2021-05-08 05:58:00+01:00  0.737567  0.737567  0.737567  0.737567   0.737567
# 2021-05-08 05:59:00+01:00  0.736435  0.736435  0.736435  0.736435   0.736435
# ...

# %%
# 5min interval data for dogecoin-usd
doge_5m = yf.download(tickers = "DOGE-USD" , interval = "5m", start="2021-04-01", end="2021-05-08")
doge_5m.to_csv('./4_yahoo_api_data/doge_5m.csv')
doge_5m
# Out:
# [*********************100%***********************]  1 of 1 completed
#                
#
#                                   Close     Adj Close  Volume
# ...

# %% [markdown]
# ## To match the timestamp of bitcoin's sentiment score, we work on the time stamp and convert it to UTC in below

# %%
#use 'dt' as datatimes

# %%
# For nz_1m
doge_1m =pd.read_csv('./4_yahoo_api_data/nz_1m.csv')
nz_1m['dt']=pd.to_datetime(nz_1m.Datetime,format='%Y-%m-%d %H:%M')
nz_1m['dt'] = nz_1m['dt'] - timedelta(hours=12)
nz_1m['dt']=nz_1m['dt'].dt.tz_localize(None)
nz_1m['times'] = pd.to_datetime(nz_1m['dt'])
nz_1m['times'] = nz_1m['times'].dt.time
mask =(nz_1m['times'].astype(str) > '22:00')
nz_1m=nz_1m.loc[mask]
nz_1m.to_csv('./4_yahoo_api_data/nz_1m_new.csv')

# %%
# For doge_1m
doge_1m =pd.read_csv('./4_yahoo_api_data/doge_1m.csv')

doge_1m['dt']=pd.to_datetime(doge_1m.Datetime,format='%Y-%m-%d %H:%M')
doge_1m['dt'] = doge_1m['dt'] - timedelta(hours=1)
doge_1m['dt']=doge_1m['dt'].dt.tz_localize(None)
doge_1m['times'] = pd.to_datetime(doge_1m['dt'])
doge_1m['times'] = doge_1m['times'].dt.time
mask =(doge_1m['times'].astype(str) > '22:00')
doge_1m=doge_1m.loc[mask]
doge_1m.to_csv('./4_yahoo_api_data/doge_1m_new.csv')

# %%
#For eth_1m
eth_1m=pd.read_csv('./4_yahoo_api_data/1m_eth.csv')

eth_1m['dt']=pd.to_datetime(eth_1m.Datetime,format='%Y-%m-%d %H:%M')
eth_1m['dt'] = eth_1m['dt'] - timedelta(hours=1)
eth_1m['dt']=eth_1m['dt'].dt.tz_localize(None)
eth_1m['times'] = pd.to_datetime(eth_1m['dt'])
eth_1m['times'] = eth_1m['times'].dt.time
mask =(eth_1m['times'].astype(str) > '22:00')
eth_1m=eth_1m.loc[mask]
eth_1m.to_csv('./4_yahoo_api_data/eth_1m_new.csv')

# %%
#For bitcoin 1m
btc_1m = pd.read_csv('./ALL_other_data/btc/1m_btc.csv')

btc_1m['dt']=pd.to_datetime(btc_1m.Datetime,format='%Y-%m-%d %H:%M')
btc_1m['dt'] = btc_1m['dt'] - timedelta(hours=1)
btc_1m['dt']=btc_1m['dt'].dt.tz_localize(None)
btc_1m['times'] = pd.to_datetime(btc_1m['dt'])
btc_1m['times'] = btc_1m['times'].dt.time
mask =(btc_1m['times'].astype(str) > '22:00')
btc_1m=btc_1m.loc[mask]
btc_1m.to_csv('./4_yahoo_api_data/btc_1m_new.csv')

# %% [markdown]
# ## Then,manually check the csv file, to make sure we left data for 2021-05-04 to 2021-05-07, and give them new name
#
# ### btc_1m_new.csv  -> final_btc.csv;
# ### eth_1m_new.csv  -> final_eth.csv;
# ### doge_1m_new.csv -> final_doge.csv;
# ### nz_1m_new.csv -> final_NZindex.csv;
